# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## 📂 Data Loading
#
# We load the dataset from a CSV file and take a first look.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.model_selection import train_test_split
from matplotlib import cm
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %%
df=pd.read_csv("Dataset.csv")
df
# Out:
#        Unnamed: 0                        State  Year       Season  \
# 0               1  Andaman and Nicobar Islands  2000  Kharif
# 1               2  Andaman and Nicobar Islands  2000  Kharif
# 2               3  Andaman and Nicobar Islands  2000  Kharif
# 3               4  Andaman and Nicobar Islands  2000  Whole Year
# 4               5  Andaman and Nicobar Islands  2000  Whole Year
# ...           ...                          ...   ...          ...
# 18726       18727                        Bihar  1998  Kharif
# 18727       18728                        Bihar  1998  Kharif
# 18728       18729                        Bihar  1998  Rabi
# 18729       18730                        Bihar  1998  Rabi
# 18730       18731                        Bihar  1998   Rabi
#
#                       Crop    Area  Production  Rainfall
# 0                 Arecanut  1254.0      2000.0    3050.8
# 1      Other Kharif pulses     2.0         1.0    3050.8
# ...

# %% [markdown]
# ## 🔍 Data Exploration
#
# We check the shape of the dataset and look for missing values.

# %%
df.shape
# Out:
# (18731, 8)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# State         0
# Year          0
# Season        0
# Crop          1
# Area          2
# Production    1
# Rainfall      1
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18731 entries, 0 to 18730
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  18731 non-null  int64
#  1   State       18731 non-null  object
#  2   Year        18731 non-null  int64
#  3   Season      18731 non-null  object
#  4   Crop        18730 non-null  object
#  5   Area        18729 non-null  float64
#  6   Production  18730 non-null  float64
#  7   Rainfall    18730 non-null  float64
# dtypes: float64(3), int64(2), object(3)
# memory usage: 1.1+ MB

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Before filtering
plt.figure(figsize=(8, 4))
sns.boxplot(x=df["Area"])
plt.title("Before Removing Outliers")
plt.show()

# Outlier removal
low_outliers = df["Area"].quantile(0.1)
high_outliers  = df["Area"].quantile(0.90)
df = df[(df["Area"] < high_outliers) & (df["Area"] > low_outliers)]
df = df.reset_index(drop=True)

# After filtering
plt.figure(figsize=(8, 4))
sns.boxplot(x=df["Area"])
plt.title("After Removing Outliers")
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np

ax = df["State"].value_counts().plot.bar(
    figsize=(18, 8),
    color=cm.get_cmap('Spectral')(np.linspace(0, 1, df["State"].nunique()))
)
plt.title("Crop Records by State")
plt.xlabel("State")
plt.ylabel("Count")
plt.xticks(rotation=90)
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np

season_counts = df["Season"].value_counts(ascending=True)
ax = season_counts.plot.barh(
    figsize=(18, 8),
    color=cm.get_cmap('plasma')(np.linspace(0, 1, len(season_counts)))
)
plt.title("Crop Records by Season")
plt.xlabel("Count")
plt.ylabel("Season")
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np

crop_counts = df["Crop"].value_counts()
ax = crop_counts.plot.bar(
    figsize=(22, 8),
    color=cm.get_cmap('viridis')(np.linspace(0, 1, len(crop_counts)))
)
plt.title("Crop Records by Crop Type")
plt.xlabel("Crop")
plt.ylabel("Count")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## ✅ Next Steps
#
# Continue with data cleaning, feature engineering, modeling, and evaluation.
